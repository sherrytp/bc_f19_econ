# %% [markdown]
# # Problem Set 4
# ## Forecasting/Predictive Analysis
#
#
# --------------------------------
#
# #### **Name: Sherry Peng Tian**
# #### **Date: Nov. 19, 2019**
#
#
#
# ### Hyndman Book Chapter 7.8
# ### Exercise 1

# %%
# Set up and install packages 
library(ggplot2)
library(fpp2)
library(seasonal)
# Out:
# Loading required package: forecast
# Warning message:
# “package ‘forecast’ was built under R version 3.5.2”Loading required package: fma
# Loading required package: expsmooth

# %%
ses(pigs, h = 4, initial = c("optimal", "simple"), 
    alpha = NULL, # how to get alpha and that l_0
    lambda = NULL, biasadj = FALSE)

#ses(pigs, h = 4, levels = c(y + 1.96*std(pigs), y - 1.96*std(pigs), 
#    alpha = NULL, lambda = NULL, biasadj = FALSE)
# Out:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Sep 1995       98816.41 85605.43 112027.4 78611.97 119020.8
# Oct 1995       98816.41 85034.52 112598.3 77738.83 119894.0
# Nov 1995       98816.41 84486.34 113146.5 76900.46 120732.4
# Dec 1995       98816.41 83958.37 113674.4 76092.99 121539.8

# %% [markdown]
# ### Exercise 5
#
# > Problem with my data???

# %%
autoplot(books)
# The dataset is not seasonal 
books %>% 
    seas() %>% 
    autoplot()
# Out:
# Error in seas(.): start year of 'x' must be > 999.
# Traceback:
#
# 1. books %>% seas() %>% autoplot()
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. seas(.)
# 9. stop("start year of 'x' must be > 999.")
# plot without title

# %%
books[1] %>% 
    ses(h = 4) %>% 
    autoplot()
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title

# %%
books[1] %>% 
    ses(h = 4) %>% 
    autoplot()
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title

# %%
# train/test split 
accurary()
# Out:
# Error in accurary(): could not find function "accurary"
# Traceback:

# %% [markdown]
# ### Exercise 6

# %%
# a. 
holt(y=books, h = 4, damped = FALSE, level = c(80, 95), fan = FALSE,
  initial = c("optimal", "simple"), exponential = FALSE,
  alpha = NULL, beta = NULL, phi = NULL, lambda = NULL,
  biasadj = FALSE)
holt(y=books[2], h = 4, damped = FALSE, level = c(80, 95), fan = FALSE,
  initial = c("optimal", "simple"), exponential = FALSE,
  alpha = NULL, beta = NULL, phi = NULL, lambda = NULL,
  biasadj = FALSE, x = y, ...)
# Out:
# Error in ets(x, "AAN", alpha = alpha, beta = beta, phi = phi, damped = damped, : y should be a univariate time series
# Traceback:
#
# 1. holt(y = books, h = 4, damped = FALSE, level = c(80, 95), fan = FALSE,
#  .     initial = c("optimal", "simple"), exponential = FALSE, alpha = NULL,
#  .     beta = NULL, phi = NULL, lambda = NULL, biasadj = FALSE)
# 2. forecast(ets(x, "AAN", alpha = alpha, beta = beta, phi = phi,
#  .     damped = damped, opt.crit = "mse", lambda = lambda, biasadj = biasadj),
#  .     h, level = level, fan = fan, ...)
# 3. ets(x, "AAN", alpha = alpha, beta = beta, phi = phi, damped = damped,
#  .     opt.crit = "mse", lambda = lambda, biasadj = biasadj)
# 4. stop("y should be a univariate time series")

# %%
# b. 
compare
# Out:
# Error in eval(expr, envir, enclos): object 'compare' not found
# Traceback:

# %% [markdown]
# - c. Discuss the merits of the two forecasting methods for these data sets. Compare the forecasts for the two series using both methods. Which do you think is best?

# %% [markdown]
# ### Exercise 8

# %%
# a. 
retaildata <- readxl::read_excel("data/retail.xlsx", skip = 1)
myts <- ts(retaildata[, "A3349588R"], 
           frequency = 12, start = c(1982, 4))
# Decomposition graph
myts %>% decompose(type = "additive") %>% 
  autoplot() + xlab("Year") 
myts %>% decompose(type="multiplicative") %>%
  autoplot() + xlab("Year") +
  ggtitle("Classical multiplicative decomposition")
# Out:
# plot without title
# plot without title

# %% [markdown]
# - a. Why is multiplicative seasonality necessary?

# %%
# b. 
myts1 <- holt(y = myts, h = 10, damped = FALSE, level = c(80, 95), fan = FALSE,
  initial = c("optimal", "simple"), exponential = FALSE,
  alpha = NULL, beta = NULL, phi = NULL, lambda = NULL,
  biasadj = FALSE, method = "multiplicative") 
myts1 
autoplot(myts1)
# Out:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Jan 2014       7.069705 5.656643 8.482767 4.908613 9.230797
# Feb 2014       7.083560 5.643198 8.523921 4.880717 9.286402
# Mar 2014       7.097415 5.630201 8.564628 4.853505 9.341324
# Apr 2014       7.111270 5.617627 8.604913 4.826940 9.395599
# May 2014       7.125125 5.605453 8.644796 4.800988 9.449262
# Jun 2014       7.138980 5.593660 8.684300 4.775617 9.502343
# Jul 2014       7.152835 5.582228 8.723441 4.750800 9.554870
# Aug 2014       7.166690 5.571141 8.762238 4.726509 9.606871
# Sep 2014       7.180545 5.560383 8.800707 4.702721 9.658369
# Oct 2014       7.194400 5.549938 8.838862 4.679412 9.709388
# plot without title

# %%
# c. ???? two methods ??

# %%
# d. 
checkresiduals(myts1)
checkresiduals(myts2)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Holt's method
# Q* = 548.84, df = 20, p-value < 2.2e-16
#
# Model df: 4.   Total lags used: 24
# Error in is.element("lm", class(object)): object 'myts2' not found
# Traceback:
#
# 1. checkresiduals(myts2)
# 2. is.element("lm", class(object))
# plot without title

# %%
# e. 
RMSE
# Out:
# Error in eval(expr, envir, enclos): object 'RMSE' not found
# Traceback:

# %% [markdown]
# ### Exercise 9
#
# `stl, box-cox, ets` on seasonally adj. ?
