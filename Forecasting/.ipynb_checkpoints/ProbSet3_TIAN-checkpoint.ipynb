# %% [markdown]
# # Problem Set 3
# ## Forecasting/Predictive Analysis
#
#
# --------------------------------
#
# #### **Name: Sherry Peng Tian**
#
# #### **Date: Nov. 12, 2019**
#
#
# > I also did one problem for chapter 5 in my spare time but the ps3 of chapter 6 is after that.
#
# ### Hyndman Book Chapter 5.10
# ### Exercise 1

# %%
# Set up and install packages 
library(ggplot2)
library(fpp2)
# Out:
# Loading required package: forecast
# Warning message:
# “package ‘forecast’ was built under R version 3.5.2”Loading required package: fma
# Loading required package: expsmooth

# %%
daily20 <- head(elecdaily, 20)
autoplot(daily20, facets = TRUE)
# Out:
# plot without title

# %% [markdown]
# - Why is there a positive relationship?
#
# There is a positive relationship between Temperature and Demand, because when the temperature raises among the time, people need to use the Airconditioning more often, resulting in a larger use of electricity.

# %%
daily20 %>%
  as.data.frame() %>%
  ggplot(aes(x=Temperature, y=Demand)) +
  geom_point() +
  geom_smooth(method="lm", se=FALSE)
# Out:
# plot without title

# %%
fit <- tslm(Demand ~ Temperature, data=daily20)
checkresiduals(fit)
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 5
#
# data:  Residuals from Linear regression model
# LM test = 3.8079, df = 5, p-value = 0.5774
# plot without title

# %% [markdown]
# - Is the model adequate? Are there any outliers or influential observations?
#
# The model is not quite adequate, from my perspective because the distribution of OLS regression residuals is not normal or splattered around 0 even though there is no clear clue of autocorrelation from the ACF chart.

# %%
forecast(fit, newdata=data.frame(Temperature=c(15,35)))
# Out:
#          Point Forecast    Lo 80    Hi 80     Lo 95    Hi 95
# 3.857143       140.5701 108.6810 172.4591  90.21166 190.9285
# 4.000000       275.7146 245.2278 306.2014 227.57056 323.8586

# %% [markdown]
# ### Hyndman Book Chapter 6.9
# ### Exercise 3

# %%
retaildata <- readxl::read_excel("data/retail.xlsx", skip = 1)
# skip=1 is required because the Excel sheet has two header rows 
samplets <- ts(retaildata[, "A3349873A"], 
               frequency = 12, start = c(1982, 4))
myts <- ts(retaildata[, "A3349588R"], 
           frequency = 12, start = c(1982, 4))
autoplot(myts)
# Out:
# plot without title

# %%
library(seasonal)
fit <- seas(myts, x11 = "") #title = "Retail Data A3349588R"
autoplot(fit)
# Out:
# plot without title

# %% [markdown]
# Before decomposition, we assume there is a strong seasonal trend within the data distribution, but actually, from the "seasonal part" decomposition, the seasonal trend fluctuates more approaching the present time, which is not entirely following the definition of seasonality. Additionally, the remainer graph shows that there is more noise from 1990 to 2005 and there is a high peak around 2010 (and then drop) for the retail data.

# %% [markdown]
# ### Exercise 4
#
# - a. From the decomposition, we find that there is upward trend for the data, the number of persons in the civilian labor force in Australia from Feb. 1978 to Aug. 1995. There is also a strong signal of seasonality going on, and the seasonal trend flutuates more approaching the end. However, the remainder graph draws attention to the drops around 1991-1993. The seasonal component from decomposition in monthly format indicates the decreasing trend from February to August, and then kind of noisy at the end of each year.
#
# - b. Yes, definitely the remainder graph could be explained by the recession of 1991/1992 because those unusual drops came from the loss of labor population. Meanwhile, the monthly seasonal component says the same from convex shapes.

# %% [markdown]
# ### Exercise 5

# %%
# a. 
autoplot(cangas)
ggsubseriesplot(cangas)
ggseasonplot(cangas)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# - a. The effect of the changing seasonality of `cangas` is shown through more patterns of seasonality happening in the recent time compared to the past before 1970s. Less gas is produced in the middle of each year compared to more from November to February, maybe because gas demand is needed less in the summer when families are not heating up, so the production was adjusted accordingly.

# %%
# b. 
cangas %>% 
    stl(s.window = 7) %>% 
        autoplot() + 
            ggtitle("STL Decomposition")
# s.window = span(in lags) of the loss window for the seasonal extraction; 
        # need to be odd and at least 7, but slow down with large data 
# t.window = smoothing window with larger range for trend
# Out:
# plot without title

# %%
# c. 
cangas %>% 
    seas(, x11 = "") %>% 
    autoplot() + 
    ggtitle("X11")
cangas %>% 
    seas() %>% 
    autoplot() + 
    ggtitle("SEATS")
# Out:
# plot without title
# plot without title

# %% [markdown]
# - x11 can handle trading day variation, holiday effects and the effects of known predictors, those special count of dates. It handles both additive and multiplicative decomposition.
# - SEATS stands for "Seasonal Extraction in ARIMA Time Series" and can only work with monthly or quarterly data.
# - STL stands for “Seasonal and Trend decomposition using Loess”, while Loess is a method for estimating nonlinear relationships. It is a versatile and robust method for decomposing time series.
# --------------------------------------
#
# - c. The advantage of using STL is that people can always choose to adjust the seasonality and robustness of the model and decomposition. Since X11 is a more robust model, it allows  the seasonal component to vary slowly over time, which explains the smoothness of cycle-trend decomposition line compared to SEATS. Therefore, SEATS method clusters lots of remainders for the beginning part of the data to seasonality rather than noise.

# %% [markdown]
# ### Exercise 6
#
#
#
# > Q: We will use the bricksq data (Australian quarterly clay brick production. 1956–1994) for this exercise.
#
# 1. Use an STL decomposition to calculate the trend-cycle and seasonal indices. (Experiment with having fixed or changing seasonality.)
# 2. Compute and plot the seasonally adjusted data.
# 3. Use a naïve method to produce forecasts of the seasonally adjusted data.
# 4. Use stlf() to reseasonalise the results, giving forecasts for the original data.
# 5. Do the residuals look uncorrelated?
# 6. Repeat with a robust STL decomposition. Does it make much difference?
# 7. Compare forecasts from stlf() with those from snaive(), using a test set comprising the last 2 years of data. Which is better?

# %%
# a. Experiment with having fixed or changing seasonality? 
bricksq %>% 
    stl(s.window = 7, t.window = 11) -> fit 
autoplot(fit)
fit
# Out:
#  Call:
#  stl(x = ., s.window = 7, t.window = 11)
#
# Components
#             seasonal    trend    remainder
# 1956 Q1 -19.49114076 198.1711  10.31999207
# 1956 Q2   4.60332304 200.0699  -0.67323206
# 1956 Q3  14.62573876 201.9687  -8.59440811
# 1956 Q4   0.57588072 204.0769  -7.65275119
# 1957 Q1 -20.03829659 206.1851   0.85322500
# 1957 Q2   4.60369768 209.8352  -0.43892106
# 1957 Q3  15.08766297 213.4854  -1.57303814
# 1957 Q4   0.79015870 217.7148   4.49500442
# 1958 Q1 -21.05466827 221.9443  -1.88963032
# 1958 Q2   4.61978314 225.8355  -1.45524021
# 1958 Q3  16.09772147 229.7266   3.17566298
# 1958 Q4   1.35168590 234.3022  -1.65384865
# 1959 Q1 -23.53016693 238.8777  -7.34754302
# 1959 Q2   4.31970198 244.1403   4.53999536
# 1959 Q3  18.32102224 249.4029  -0.72391761
# 1959 Q4   1.91742819 254.8993  -1.81672016
# 1960 Q1 -23.12801968 260.3957   4.73233111
# 1960 Q2   4.02069568 262.5938   1.38550895
# 1960 Q3  18.52081113 264.7919   6.68728668
# 1960 Q4  -0.19591692 262.1662  15.02970670
# 1961 Q1 -22.25141818 259.5405   3.71089991
# 1961 Q2   3.29822486 256.1838  -6.48203515
# 1961 Q3  19.38101854 252.8271  -7.20812084
# 1961 Q4   0.58894075 252.0059 -16.59485656
# 1962 Q1 -23.00225318 251.1847   0.81752387
# 1962 Q2   1.39855405 253.4314  10.17009098
# 1962 Q3  19.71334786 255.6780  -0.39132850
# 1962 Q4   1.69988094 261.5555  -5.25533808
# 1963 Q1 -24.54841773 267.4329 -11.88451591
# 1963 Q2   2.34868372 277.4851 -16.83375568
# 1963 Q3  20.41157266 287.5372   0.05121704
# 1963 Q4   3.54276326 299.3207  10.13652088
# 1964 Q1 -27.72405315 311.1042   9.61983173
# 1964 Q2   3.20153310 319.7188   5.07965666
# 1964 Q3  21.37325034 328.3334  -0.70664940
# 1964 Q4   3.93749162 332.4369   3.62560912
# 1965 Q1 -28.74793907 336.5404   1.20753961
# 1965 Q2   6.28338373 337.8366   4.88001472
# 1965 Q3  20.17927037 339.1328   6.68792599
# 1965 Q4   0.92377070 339.4935  -0.41730113
# 1966 Q1 -27.68696188 339.8543 -10.16729535
# 1966 Q2   8.75837489 340.7781   0.46356490
# 1966 Q3  18.12796934 341.7019   2.17016746
# 1966 Q4  -0.26652500 343.8400  -6.57346564
# 1967 Q1 -26.74051755 345.9781   6.76239948
# 1967 Q2   7.50210806 349.9183   0.57963912
# 1967 Q3  17.66577099 353.8584 -12.52415857
# 1967 Q4   1.46493771 360.7763  -5.24124454
# 1968 Q1 -25.93174167 367.6942  -0.76248442
# 1968 Q2   5.68551470 377.7253  -3.41083983
# 1968 Q3  18.62651691 387.7564  -2.38294107
# 1968 Q4   3.45883953 397.3931   8.14803942
# 1969 Q1 -28.35889387 407.0298   4.32907595
# 1969 Q2   5.33159900 412.5496  -0.88116001
# 1969 Q3  20.94091665 418.0693  14.98977926
# 1969 Q4   4.13841548 418.8698   4.99177338
# 1970 Q1 -32.42413730 419.6703  -1.24618088
# 1970 Q2   6.82501878 419.1082   2.06682234
# 1970 Q3  23.18964275 418.5460  -7.73564232
# 1970 Q4   3.96116350 419.9353  -6.89651130
# 1971 Q1 -34.58191000 421.3247  -1.74278603
# 1971 Q2   5.67069112 425.3750   1.95433189
# 1971 Q3  23.13863034 429.4253   0.43611171
# 1971 Q4   4.86337269 435.8291  -4.69247935
# 1972 Q1 -33.27355831 442.2330  -9.95939706
# 1972 Q2   3.62665056 449.7992   7.57411858
# 1972 Q3  27.06515876 457.3655  -8.43066511
# 1972 Q4   3.48824390 466.5067   7.00501391
# 1973 Q1 -36.71830822 475.6480  13.07033020
# 1973 Q2   7.18829110 485.0890 -31.27730700
# 1973 Q3  32.96110207 494.5301   6.50884415
# 1973 Q4  -0.79507860 494.1717  22.62341169
# 1974 Q1 -44.40959809 493.8133  28.59631806
# 1974 Q2   9.93509365 480.2031  35.86180065
# 1974 Q3  36.73117551 466.5929  14.67589312
# 1974 Q4  -1.05260973 451.8899 -33.83731440
# 1975 Q1 -50.43176219 437.1869 -46.75515471
# 1975 Q2  15.64225171 437.3493 -15.99154421
# 1975 Q3  38.00380891 437.5117 -16.51547701
# 1975 Q4   0.98685833 453.0907  -5.07757895
# 1976 Q1 -55.20438120 468.6698  10.53460807
# 1976 Q2  16.63901320 482.0776   2.28342668
# 1976 Q3  32.21574610 495.4853  12.29890679
# 1976 Q4   4.83112820 498.4656  29.70325228
# 1977 Q1 -50.82860889 501.4459   6.38271696
# 1977 Q2  14.70004716 495.5165   2.78349708
# 1977 Q3  25.98970013 489.5870   6.42328028
# 1977 Q4   8.24369903 481.9993 -12.24304432
# 1978 Q1 -45.59664014 474.4117  -7.81503084
# 1978 Q2  12.30508111 475.7964  -1.10145089
# 1978 Q3  25.21558454 477.1811 -32.39665314
# 1978 Q4   7.33420247 489.0274 -14.36163336
# 1979 Q1 -43.51008970 500.8738   0.63629651
# 1979 Q2   9.35257696 515.4284   1.21903243
# 1979 Q3  23.71659319 529.9830  19.30041878
# 1979 Q4   7.95620277 539.3742  15.66961122
# 1980 Q1 -42.44616177 548.7654   6.68077778
# 1980 Q2  11.81206724 552.3973 -13.20933888
# 1980 Q3  25.94117920 556.0292   7.02966149
# 1980 Q4   8.53638069 557.7621  -2.29847347
# 1981 Q1 -48.13829176 559.4950   7.64326551
# 1981 Q2  18.67689067 558.7672   3.55590987
# 1981 Q3  28.78475545 558.0394  -5.82412813
# 1981 Q4   3.38770845 543.8618  30.75045220
# 1982 Q1 -55.62354189 529.6843  25.93923589
# 1982 Q2  24.42229224 500.5585  35.01921570
# 1982 Q3  27.39660790 471.4327  13.17071399
# 1982 Q4   0.96155056 445.2777 -34.23926669
# 1983 Q1 -54.88267566 419.1228 -61.24007850
# 1983 Q2  26.04177043 413.1558 -30.19757588
# 1983 Q3  28.00097951 407.1889 -15.18983626
# 1983 Q4  -0.05032705 419.8633  -6.81300949
# 1984 Q1 -52.90644303 432.5378  20.36862671
# 1984 Q2  20.71282811 447.5591   0.72807890
# 1984 Q3  28.27850613 462.5804  -8.85887580
# 1984 Q4   0.16759597 472.8556  10.97677339
# 1985 Q1 -45.78648796 483.1309   9.65559635
# 1985 Q2  18.61162013 487.9575   0.43092417
# 1985 Q3  28.57650581 492.7840  11.63947439
# 1985 Q4  -2.96464494 489.7768  16.18788580
# 1986 Q1 -44.28923172 486.7695   0.51973324
# 1986 Q2  19.70610835 480.2681   3.02575283
# 1986 Q3  31.87739725 473.7668  -0.64417641
# 1986 Q4  -6.87318980 469.2811 -19.40787823
# 1987 Q1 -47.24282505 464.7954  -2.55253185
# 1987 Q2  20.97505923 466.4100  -2.38509164
# 1987 Q3  32.88670535 468.0247  -5.91141327
# 1987 Q4  -8.32300566 478.1258 -11.80279091
# 1988 Q1 -46.20885508 488.2269 -15.01803013
# 1988 Q2  22.81213985 502.5411  -6.35320208
# 1988 Q3  30.61095505 516.8552   7.53380571
# 1988 Q4  -5.18343798 526.9034  17.28001895
# 1989 Q1 -46.98053125 536.9516  21.02893243
# 1989 Q2  22.70339381 535.8617  13.43493197
# 1989 Q3  26.37586223 534.7717   8.85238814
# 1989 Q4   1.61347048 522.6158   1.77068820
# 1990 Q1 -45.99293971 510.4599   7.53300669
# 1990 Q2  19.34834596 492.1835  12.46820260
# 1990 Q3  22.29324769 473.9070   0.79978244
# 1990 Q4   4.73238296 457.1696  -1.90199591
# 1991 Q1 -43.01406312 440.4323 -24.41819292
# 1991 Q2  14.75706250 430.8146  -9.57163316
# 1991 Q3  21.89412757 421.1969 -19.09101285
# 1991 Q4   2.92864537 419.3373   7.73403962
# 1992 Q1 -40.26061057 417.4777   9.78286583
# 1992 Q2  14.00029188 420.5077 -21.50804107
# 1992 Q3  24.22096303 423.5378   3.24128333
# 1992 Q4   1.77826153 428.4158 -10.19402770
# 1993 Q1 -39.52771821 433.2938   0.23393951
# 1993 Q2  13.03840427 439.3083   9.65330308
# 1993 Q3  24.98276558 445.3228   5.69442782
# 1993 Q4   1.16791477 450.9668  -9.13467164
# 1994 Q1 -39.01705571 456.6107   3.40634857
# 1994 Q2  12.63274483 462.0156  -2.64830506
# 1994 Q3  25.50780529 467.4204   1.07178140
# plot without title

# %%
# b. 
fit %>% 
    seasadj() %>% 
        autoplot()
# Out:
# plot without title

# %%
# c. 
fit %>% 
    seasadj() %>% 
    naive() %>% 
        autoplot()
# Out:
# plot without title

# %%
# d 
stlf_model <- bricksq %>% 
    stlf(s.window = "periodic", method = "naive") %>% 
    forecast()
plot(stlf_model)
# Out:
# Plot with title “Forecasts from STL +  Random walk”

# %%
checkresiduals(stl_model)
# Out:
# Error in is.element("lm", class(object)): object 'stl_model' not found
# Traceback:
#
# 1. checkresiduals(stl_model)
# 2. is.element("lm", class(object))

# %% [markdown]
# - e. The residuals look uncorrelated because the p-value for Ljung-Box test is less than 0.05, meaning the test is statistically significant at above 95% confidence level. Moreover, the residuals are normally distributed, flutuating around zero axis. However, there must be some noise from autocorrelation, referring to the ACF graph.

# %% [markdown]
# > `stlf()`: h = number of periods for forecasting, level = confidence level, lambda = "auto" Box-Cox transformation, s.window, t.window, robust = TRUE, method = "arima, naive, ..."

# %%
# f. 
stl_robust <- bricksq %>% 
    stl(s.window = "periodic", robust = TRUE) %>% 
    forecast()
plot(stl_robust)
checkresiduals(stl_robust)
# Out:
# Warning message in checkresiduals(stl_robust):
# “The fitted degrees of freedom is based on the model used for the seasonally adjusted data.”
# Plot with title “Forecasts from STL +  ETS(M,N,N)”
# 	Ljung-Box test
#
# data:  Residuals from STL +  ETS(M,N,N)
# Q* = 20.424, df = 6, p-value = 0.002326
#
# Model df: 2.   Total lags used: 8
# plot without title

# %% [markdown]
# - f. There is more autocorrelation with robust `stlf()` model, maybe because the robust systems much less noise.
#
# - g. Judging from ME, RMSE, MAE, and MASE those common prediction accuracy rates, definitely `stlf()` method works better with the last 2 years of prediction. However, when parsing the data, I found that there is two missing quarterly values for those last 2 years, which might cause question to the comparison result.

# %%
# g. 
train <- window(bricksq, end = c(1992,4))
test <- window(bricksq, start = 1993)
autoplot(bricksq) + 
    autolayer(train, series = "Train") + 
    autolayer(test, series = "Test")
# Out:
# plot without title

# %%
# snaive
nfit <- train %>% 
    # seasonally adjusted  %>% 
    naive() %>% 
    forecast(h = 4*2) 
accuracy(nfit, test) 
# stlf
sfit <- train %>% 
    stl(s.window = "periodic") %>% 
    forecast(h = 4*2)
accuracy(sfit, test)
# Out:
#              ME        RMSE     MAE      MPE        MAPE     MASE
# Training set  1.571429 40.95617 32.86395 0.03564104 8.213401 0.9071129
# Test set     31.714286 45.17585 39.14286 6.52610567 8.411530 1.0804239
#              ACF1         Theil's U
# Training set -0.082210792       NA
# Test set     -0.007326224 1.115584
#              ME        RMSE     MAE      MPE       MAPE     MASE
# Training set  1.293215 22.94146 17.25340 0.2981726 4.522977 0.4762296
# Test set     34.270190 36.26371 34.27019 7.4809867 7.480987 0.9459282
#              ACF1       Theil's U
# Training set 0.07899911        NA
# Test set     0.17243754 0.9161642
